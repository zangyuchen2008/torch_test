# %%
# %config Completer.use_jedi = False

# %%
from transformers import AutoModel,AutoConfig,AutoTokenizer
import torch

# %%
config = AutoConfig.from_pretrained('/data/yuchen/projects/test/transformers_test/model/distilbert/config.json')
model = AutoModel.from_config(config)

# %%
tokenizer = AutoTokenizer.from_pretrained('/data/yuchen/projects/test/transformers_test/model/distilbert')

# %%
inputs = tokenizer('hello world',return_tensors='pt')
output =model(**inputs)

# %%
output['last_hidden_state'][0][0].shape
# Out:
# torch.Size([768])

# %%
input = torch.randn(3, 5, requires_grad=True)
target = torch.randint(5, (3,), dtype=torch.int64)
loss = torch.nn.functional.cross_entropy(input, target)
# loss.backward()
loss
# Out:
# tensor(2.7036, grad_fn=<NllLossBackward>)

# %%
inputs= torch.randint(10,(10,20))

# %%
label = torch.randint(2,(10,))

# %%
from torch.utils.data import DataLoader

# %%
dl = DataLoader(inputs,batch_size=3,shuffle=True)
dl = DataLoader(inputs,batch_size=3,shuffle=False)

# %%
aa =  [('hello',1),('world',0),('game',1)]

# %%
dl = DataLoader(aa,batch_size=2,shuffle=True)

# %%
for a in dl:
    print(a)
# Out:
# [('hello', 'world'), tensor([1, 0])]
# [('game',), tensor([1])]

# %%
def generate(ls):
    for e in ls:
        yield e**2

# %%
a = list(range(10))

# %%
g = generate(a)

# %%
next(g)
# Out:
# 25

# %%
f = open('test.csv','w')
f.write('adad')
f.write('adadasd')
f.close()

# %%
with open('test.csv','w') as f:
    for index , i in enumerate(range(20)):
        f.write(str(index))
        f.write(':')
        f.write(str(i))
        f.write('\n')

# %%
import re

# %%
re.findall('\$[0-9]+','$999.99')
# Out:
# ['$999']

# %%
re.findall('\$[0-9]+','$999.99')
# Out:
# ['$999']

# %%
re.findall('ˆ(?=Volcano)[A-Za-z]+','Volcano hello world')
# Out:
# []

# %%
re.split('[a(bc)]','abcdeeadvf')
# Out:
# ['', '', '', 'dee', 'dvf']

# %%
def gen():
    for line in open('test.csv','r'):
        result  = line.split(':')[1]
        yield result

# %%
g = gen()

# %%
next(g)
# Out:
# '9\n'
